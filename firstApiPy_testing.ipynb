# %%
import sys
# This path will be different on your machine. Please change it accordingly.
project_path = 'C:\Users\stacy\OneDrive\Projects\scouting17\irsScouting2017\Server'
sys.path.append(project_path)
# Let's verify the path was added. The syntax below works because the data type of sys.path is Python List.
sys.path[-3:]
# Out:
# ['C:\\Users\\stacy\\OneDrive\\Projects\\scouting17\\irsScouting2017\\Server',
#  'C:\\Users\\stacy\\OneDrive\\Projects\\scouting17\\irsScouting2017\\Server',
#  'C:\\Users\\stacy\\OneDrive\\Projects\\scouting17\\irsScouting2017\\Server']

# %% [markdown]
# ## Get a Database Connection
# We can get a database engine from the irsScouting system, or directly from the database server via the sqlalchemy package.

# %%
# From irsScouting
import scouting.db as db
engine = db.getdbengine()

# %%
# Directly from Postgresql via sqlalchemy
import sqlalchemy as sa
connection_string = 'postgresql://irs1318:irs1318@localhost:5432/scouting'
engine = sa.create_engine(connection_string)

# %% [markdown]
# ## Get a Rankings Table

# %%
import scouting.output as out
tasks = ['moveBaseline', 'placeGear','shootHighBoiler', 'shootLowBoiler']
ranks = out.get_rankings(tasks = tasks, excel_file = None)

# %%
ranks['auto'].head()
# Out:
# task  moveBaseline                          placeGear                         \
#      sum_successes sum_attempts percent sum_successes sum_attempts   percent
# team
# 1258           5.0          4.0    1.25           2.0          0.0       inf
# 1294           7.0          7.0    1.00           3.0          1.0  3.000000
# 1318           6.0          4.0    1.50           3.0          0.0       inf
# 1899           2.0          5.0    0.40           1.0          0.0       inf
# 1983           7.0          7.0    1.00           5.0          0.0       inf
#
# task shootHighBoiler                      shootLowBoiler
#        sum_successes sum_attempts percent  sum_successes sum_attempts percent
# team
# 1258             NaN          NaN     NaN            NaN          NaN     NaN
# 1294             NaN          NaN     NaN            0.0          0.0     NaN
# 1318             2.0          2.0     1.0            NaN          NaN     NaN
# ...

# %%
ranks.sort_values(by=('teleop', 'placeGear', 'sum_successes'), ascending = False)[('teleop')].head(10)
# Out:
# task     placeGear                        shootHighBoiler               \
#      sum_successes sum_attempts   percent   sum_successes sum_attempts
# team
# 4469          32.0         34.0  0.941176             0.0          3.0
# 2930          30.0         32.0  0.937500             NaN          NaN
# 5588          30.0         30.0  1.000000             6.0          8.0
# 5803          30.0         30.0  1.000000             NaN          NaN
# 2942          23.0         25.0  0.920000             NaN          NaN
# 2046          22.0         22.0  1.000000             5.0         27.0
# 1294          21.0         21.0  1.000000             2.0          6.0
# 1983          19.0         22.0  0.863636             0.0          0.0
# 2976          19.0         22.0  0.863636             NaN          NaN
# 2907          17.0         17.0  1.000000             NaN          NaN
#
# task           shootLowBoiler
#        percent  sum_successes sum_attempts percent
# team
# ...

# %%
all_ranks = out.get_rankings(excel_file = None)
all_ranks.sort_values(by=('finish', 'pushTouchPad', 'sum_successes'), ascending = False)[('finish')].head(10)
# Out:
# task      disabled                           hasRobot                       \
#      sum_successes sum_attempts percent sum_successes sum_attempts percent
# team
# 4469           NaN          NaN     NaN           NaN          NaN     NaN
# 1983           2.0          0.0     inf           NaN          NaN     NaN
# 5588           NaN          NaN     NaN           NaN          NaN     NaN
# 2930           NaN          NaN     NaN           NaN          NaN     NaN
# 1318           1.0          0.0     inf           NaN          NaN     NaN
# 2907           NaN          NaN     NaN           NaN          NaN     NaN
# 3588           NaN          NaN     NaN           NaN          NaN     NaN
# 4681           NaN          NaN     NaN           NaN          NaN     NaN
# 4131           1.0          0.0     inf           NaN          NaN     NaN
# 2046           NaN          NaN     NaN           NaN          NaN     NaN
#
# ...

# %%
import datetime as dt
dt.datetime.now().strftime("%Y%b%d_%H%M%S")
# Out:
# '2017Mar18_105918'

# %%
import scouting.event as evt
evt.EventDal.get_current_event()
# Out:
# u'waamv'
