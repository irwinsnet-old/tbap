# %% [markdown]
# ## Setup

# %%
import json
import re
import datetime
from collections import OrderedDict

import pandas as pd
import pandas.io.json as pj
from IPython.core.debugger import set_trace

import tbap.api as api
import tbap.server as server

import auth

# %%
key = auth.key
username = auth.username
sn = api.Session(username, key)
snj = api.Session(username, key, data_format="json")

# Display floating point numbers in fixed format within dataframes.
pd.options.display.float_format = '{:f}'.format

# %% [markdown]
# # Examples

# %% [markdown]
# ### get_events()

# %%
events = api.get_events(sn, year=2019)

# %%
events.query("city=='Auburn'")
# Out:
#                                              address    city country  \
# key
# 2019waahs       711 E Main St, Auburn, WA 98002, USA  Auburn     USA
# 2019waamv  28900 124th Ave SE, Auburn, WA 98092, USA  Auburn     USA
#
#           division_keys    end_date event_code  event_type event_type_string  \
# key
# 2019waahs            []  2019-03-31      waahs           1          District
# 2019waamv            []  2019-03-10      waamv           1          District
#
#           first_event_code  first_event_id  ... state_prov  \
# key                                         ...
# 2019waahs            WAAHS    37488.000000  ...         WA
# 2019waamv            WAAMV    37478.000000  ...         WA
#
#                       timezone  \
# key
# 2019waahs  America/Los_Angeles
# 2019waamv  America/Los_Angeles
#
#                                                     webcasts  \
# key
# 2019waahs  [{'channel': 'firstwa_blue1', 'type': 'twitch'...
# 2019waamv  [{'channel': 'firstwa_red1', 'type': 'twitch'}...
#
#                            website     week  year district_abbreviation  \
# key
# 2019waahs   http://www.firstwa.org 4.000000  2019                   pnw
# 2019waamv  http://www.firstwa.org/ 1.000000  2019                   pnw
#
#            district_display_name district_key district_year
# key
# 2019waahs      Pacific Northwest      2019pnw   2019.000000
# 2019waamv      Pacific Northwest      2019pnw   2019.000000
#
# [2 rows x 32 columns]

# %%
events.shape
# Out:
# (244, 32)

# %%
events = api.get_events(sn, year=2019, response="simple")

# %%
events.tail()
# Out:
#                     city country    end_date event_code  event_type  \
# key
# 2019wimi       Milwaukee     USA  2019-03-30       wimi           0
# 2019wiwi         Wolcott     USA  2019-06-01       wiwi          99
# 2019wiws      West Salem     USA  2019-02-17       wiws         100
# 2019wowcmp    Austintown     USA  2019-05-18     wowcmp          99
# 2019zhrcc   Hangzhou Shi   China  2019-08-04      zhrcc          99
#
#                                                          name  start_date  \
# key
# 2019wimi                                   Wisconsin Regional  2019-03-27
# 2019wiwi                        Where is Wolcott Invitational  2019-06-01
# 2019wiws            Seven Rivers Robotics Coalition Week Zero  2019-02-16
# 2019wowcmp                          WOW Alliance Championship  2019-05-17
# 2019zhrcc   RCC Qianjiang International Robotics Invitatio...  2019-08-01
#
#                 state_prov  year district_abbreviation district_display_name  \
# key
# 2019wimi                WI  2019                  None                  None
# 2019wiwi                CT  2019                  None                  None
# 2019wiws                WI  2019                  None                  None
# 2019wowcmp              OH  2019                  None                  None
# 2019zhrcc   Zhejiang Sheng  2019                  None                  None
#
#            district_key  district_year
# key
# 2019wimi           None            nan
# 2019wiwi           None            nan
# 2019wiws           None            nan
# 2019wowcmp         None            nan
# 2019zhrcc          None            nan

# %%
events.shape
# Out:
# (244, 13)

# %%
events = api.get_events(sn, year=2019, response="keys")

# %%
events.head()
# Out:
#         key
# 0  2019abca
# 1  2019alhu
# 2   2019arc
# 3  2019arli
# 4  2019aroz

# %%
events.shape
# Out:
# (203, 1)

# %%
events = api.get_events(sn, district="2019pnw")

# %%
events.tail()
# Out:
#                                               address          city country  \
# key
# 2019waamv   28900 124th Ave SE, Auburn, WA 98092, USA        Auburn     USA
# 2019wamou      314 N 9th St, Mt Vernon, WA 98273, USA  Mount Vernon     USA
# 2019wasno  7401 144th Pl SE, Snohomish, WA 98296, USA     Snohomish     USA
# 2019waspo  8301 E Buckeye Ave, Spokane, WA 99212, USA       Spokane     USA
# 2019wayak      1301 S Fair Ave, Yakima, WA 98901, USA        Yakima     USA
#
#           district.abbreviation district.display_name district.key  \
# key
# 2019waamv                   pnw     Pacific Northwest      2019pnw
# 2019wamou                   pnw     Pacific Northwest      2019pnw
# 2019wasno                   pnw     Pacific Northwest      2019pnw
# 2019waspo                   pnw     Pacific Northwest      2019pnw
# 2019wayak                   pnw     Pacific Northwest      2019pnw
#
#            district.year division_keys    end_date event_code  ...  \
# key                                                            ...
# 2019waamv           2019            []  2019-03-10      waamv  ...
# 2019wamou           2019            []  2019-03-03      wamou  ...
# 2019wasno           2019            []  2019-03-24      wasno  ...
# 2019waspo           2019            []  2019-03-23      waspo  ...
# 2019wayak           2019            []  2019-03-16      wayak  ...
#
#                          playoff_type_string postal_code           short_name  \
# key
# 2019waamv  Elimination Bracket (8 Alliances)       98092  Auburn Mountainview
# 2019wamou                               None       98273         Mount Vernon
# 2019wasno                               None       98296         Glacier Peak
# 2019waspo                               None       99212          West Valley
# 2019wayak                               None       98901              SunDome
#
#            start_date state_prov             timezone  \
# key
# 2019waamv  2019-03-08         WA  America/Los_Angeles
# 2019wamou  2019-03-01         WA  America/Los_Angeles
# 2019wasno  2019-03-22         WA  America/Los_Angeles
# 2019waspo  2019-03-21         WA  America/Los_Angeles
# 2019wayak  2019-03-14         WA  America/Los_Angeles
#
#                                                     webcasts  \
# key
# 2019waamv  [{'channel': 'firstwa_red1', 'type': 'twitch'}...
# 2019wamou  [{'channel': 'firstwa_red1', 'type': 'twitch'}...
# 2019wasno  [{'channel': 'firstwa_blue1', 'type': 'twitch'...
# 2019waspo  [{'channel': 'firstwa_red1', 'type': 'twitch'}...
# 2019wayak  [{'channel': 'firstwa_blue1', 'type': 'twitch'...
#
#                            website week  year
# key
# 2019waamv  http://www.firstwa.org/    1  2019
# 2019wamou  http://www.firstwa.org/    0  2019
# 2019wasno  http://www.firstwa.org/    3  2019
# 2019waspo   http://www.firstwa.org    3  2019
# 2019wayak  http://www.firstwa.org/    2  2019
#
# [5 rows x 32 columns]

# %%
events.shape
# Out:
# (10, 32)

# %%
events = api.get_events(sn, district="2019pnw", response="simple")

# %%
events.head()
# Out:
#                   city country district.abbreviation district.display_name  \
# key
# 2019orlak  Lake Oswego     USA                   pnw     Pacific Northwest
# 2019orore  Oregon City     USA                   pnw     Pacific Northwest
# 2019orwil  Wilsonville     USA                   pnw     Pacific Northwest
# 2019pncmp       Tacoma     USA                   pnw     Pacific Northwest
# 2019waahs       Auburn     USA                   pnw     Pacific Northwest
#
#           district.key  district.year    end_date event_code  event_type  \
# key
# 2019orlak      2019pnw           2019  2019-03-30      orlak           1
# 2019orore      2019pnw           2019  2019-03-16      orore           1
# 2019orwil      2019pnw           2019  2019-03-09      orwil           1
# 2019pncmp      2019pnw           2019  2019-04-06      pncmp           2
# 2019waahs      2019pnw           2019  2019-03-31      waahs           1
#
#                                                     name  start_date  \
# key
# 2019orlak                 PNW District Lake Oswego Event  2019-03-28
# 2019orore           PNW District Clackamas Academy Event  2019-03-14
# 2019orwil                 PNW District Wilsonville Event  2019-03-07
# 2019pncmp  Pacific Northwest FIRST District Championship  2019-04-03
# 2019waahs                      PNW District Auburn Event  2019-03-29
#
#           state_prov  year
# key
# 2019orlak         OR  2019
# 2019orore         OR  2019
# 2019orwil         OR  2019
# 2019pncmp         WA  2019
# 2019waahs         WA  2019

# %%
events.shape
# Out:
# (10, 13)

# %%
events = api.get_events(sn, district="2019pnw", response="keys")

# %%
events.head()
# Out:
#          key
# 0  2019orlak
# 1  2019orore
# 2  2019orwil
# 3  2019pncmp
# 4  2019waahs

# %%
events = api.get_events(sn, team="frc1318", year=2019)

# %%
events.head()
# Out:
#                                                      address          city  \
# key
# 2019pncmp            1500 Commerce St, Tacoma, WA 98402, USA        Tacoma
# 2019roe    1001 Avenida De Las Americas, Houston, TX 7701...       Houston
# 2019waahs               711 E Main St, Auburn, WA 98002, USA        Auburn
# 2019wamou             314 N 9th St, Mt Vernon, WA 98273, USA  Mount Vernon
# 2019wayak             1301 S Fair Ave, Yakima, WA 98901, USA        Yakima
#
#           country district.abbreviation district.display_name district.key  \
# key
# 2019pncmp     USA                   pnw     Pacific Northwest      2019pnw
# 2019roe       USA                   NaN                   NaN          NaN
# 2019waahs     USA                   pnw     Pacific Northwest      2019pnw
# 2019wamou     USA                   pnw     Pacific Northwest      2019pnw
# 2019wayak     USA                   pnw     Pacific Northwest      2019pnw
#
#            district.year division_keys    end_date event_code  ...  \
# key                                                            ...
# 2019pncmp    2019.000000            []  2019-04-06      pncmp  ...
# 2019roe              nan            []  2019-04-20        roe  ...
# 2019waahs    2019.000000            []  2019-03-31      waahs  ...
# 2019wamou    2019.000000            []  2019-03-03      wamou  ...
# 2019wayak    2019.000000            []  2019-03-16      wayak  ...
#
#            playoff_type_string postal_code               short_name  \
# key
# 2019pncmp                 None       98402  Pacific Northwest FIRST
# 2019roe                   None       77010                 Roebling
# 2019waahs                 None       98002                   Auburn
# 2019wamou                 None       98273             Mount Vernon
# 2019wayak                 None       98901                  SunDome
#
#            start_date state_prov             timezone  \
# key
# 2019pncmp  2019-04-03         WA  America/Los_Angeles
# 2019roe    2019-04-17         TX      America/Chicago
# 2019waahs  2019-03-29         WA  America/Los_Angeles
# 2019wamou  2019-03-01         WA  America/Los_Angeles
# 2019wayak  2019-03-14         WA  America/Los_Angeles
#
#                                                     webcasts  \
# key
# 2019pncmp  [{'channel': 'firstwa_red1', 'type': 'twitch'}...
# 2019roe    [{'channel': 'firstinspires_roebling', 'type':...
# 2019waahs  [{'channel': 'firstwa_blue1', 'type': 'twitch'...
# 2019wamou  [{'channel': 'firstwa_red1', 'type': 'twitch'}...
# 2019wayak  [{'channel': 'firstwa_blue1', 'type': 'twitch'...
#
#                            website     week  year
# key
# 2019pncmp   http://www.firstwa.org 5.000000  2019
# 2019roe                       None      nan  2019
# 2019waahs   http://www.firstwa.org 4.000000  2019
# 2019wamou  http://www.firstwa.org/ 0.000000  2019
# 2019wayak  http://www.firstwa.org/ 2.000000  2019
#
# [5 rows x 32 columns]

# %%
events.shape
# Out:
# (8, 32)

# %%
events = api.get_events(sn, team="frc1318", year=2019, response="simple")

# %%
events.head()
# Out:
#                    city country district.abbreviation district.display_name  \
# key
# 2019pncmp        Tacoma     USA                   pnw     Pacific Northwest
# 2019roe         Houston     USA                   NaN                   NaN
# 2019waahs        Auburn     USA                   pnw     Pacific Northwest
# 2019wamou  Mount Vernon     USA                   pnw     Pacific Northwest
# 2019wayak        Yakima     USA                   pnw     Pacific Northwest
#
#           district.key  district.year    end_date event_code  event_type  \
# key
# 2019pncmp      2019pnw    2019.000000  2019-04-06      pncmp           2
# 2019roe            NaN            nan  2019-04-20        roe           3
# 2019waahs      2019pnw    2019.000000  2019-03-31      waahs           1
# 2019wamou      2019pnw    2019.000000  2019-03-03      wamou           1
# 2019wayak      2019pnw    2019.000000  2019-03-16      wayak           1
#
#                                                     name  start_date  \
# key
# 2019pncmp  Pacific Northwest FIRST District Championship  2019-04-03
# 2019roe                                Roebling Division  2019-04-17
# 2019waahs                      PNW District Auburn Event  2019-03-29
# 2019wamou                PNW District Mount Vernon Event  2019-03-01
# 2019wayak                     PNW District SunDome Event  2019-03-14
#
#           state_prov  year
# key
# 2019pncmp         WA  2019
# 2019roe           TX  2019
# 2019waahs         WA  2019
# 2019wamou         WA  2019
# 2019wayak         WA  2019

# %%
events = api.get_events(sn, team="frc1318", year=2019, response="keys")

# %%
events.head()
# Out:
#          key
# 0  2019pncmp
# 1    2019roe
# 2  2019waahs
# 3  2019wamou
# 4  2019wayak

# %%
event = api.get_events(sn, event="2019tur")

# %%
event
# Out:
#                                                    address     city country  \
# key
# 2019tur  1001 Avenida De Las Americas, Houston, TX 7701...  Houston     USA
#
#          district division_keys    end_date event_code  event_type  \
# key
# 2019tur       nan            []  2019-04-20        tur           3
#
#              event_type_string first_event_code  ...  playoff_type_string  \
# key                                              ...
# 2019tur  Championship Division              TUR  ...                  nan
#
#         postal_code short_name  start_date  state_prov         timezone  \
# key
# 2019tur       77010     Turing  2019-04-17          TX  America/Chicago
#
#                                                   webcasts website  week  year
# key
# 2019tur  [{'channel': 'firstinspires_turing', 'type': '...     nan   nan  2019
#
# [1 rows x 29 columns]

# %%
event.shape
# Out:
# (1, 29)

# %%
event = api.get_events(sn, event="2019tur", response="simple")

# %%
event
# Out:
#             city country  district    end_date event_code  event_type  \
# key
# 2019tur  Houston     USA       nan  2019-04-20        tur           3
#
#                     name  start_date state_prov  year
# key
# 2019tur  Turing Division  2019-04-17         TX  2019

# %%
event.shape
# Out:
# (1, 10)

# %% [markdown]
# ### get_rankings()

# %%
rankings = api.get_event_rankings(sn, "2019pncmp")

# %%
rankings.head()
# Out:
#          team  matches_played  Total Ranking Points  Ranking Score      Cargo  \
# rank
# 1     frc2046              12                    36       3.000000 342.000000
# 2     frc4911              12                    35       2.910000 384.000000
# 3     frc4488              12                    35       2.910000 300.000000
# 4     frc2910              12                    33       2.750000 390.000000
# 5     frc2990              12                    33       2.750000 390.000000
#
#       Hatch Panel  HAB Climb  Sandstorm Bonus  wins  losses  ties  dq  \
# rank
# 1      208.000000 192.000000       174.000000    11       1     0   0
# 2      226.000000 201.000000       156.000000    10       2     0   0
# 3      178.000000 228.000000       177.000000    10       2     0   0
# 4      282.000000 192.000000       171.000000    11       1     0   0
# 5      190.000000 219.000000       147.000000    10       2     0   0
#
#      qual_average
# rank
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None

# %%
rankings.shape
# Out:
# (64, 13)
