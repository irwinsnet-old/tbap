# %% [markdown]
# ## Setup

# %%
import json
import re
import datetime
from collections import OrderedDict

import pandas as pd
import pandas.io.json as pj
from IPython.core.debugger import set_trace

import tbap.api as api
import tbap.server as server

# %%
key = "6Sx6a2gOyNWwNNTAd9UYBOpWp7MxaNrZgO4CqConwJwwDooKQV3DbZXvnk8TBL7A"
username = "stacy.k.irwin@gmail.com"
sn = api.Session(username, key)
snj = api.Session(username, key, data_format="json")

# Display floating point numbers in fixed format within dataframes.
pd.options.display.float_format = '{:f}'.format

# %% [markdown]
# # Examples

# %% [markdown]
# ### get_events()

# %%
events = api.get_events(sn, year=2016)

# %%
events.query("city=='Auburn'")
# Out:
#                                              address    city country  \
# key
# 2016waahs       711 E Main St, Auburn, WA 98002, USA  Auburn     USA
# 2016waamv  28900 124th Ave SE, Auburn, WA 98092, USA  Auburn     USA
#
#           division_keys    end_date event_code  event_type event_type_string  \
# key
# 2016waahs            []  2016-04-03      waahs           1          District
# 2016waamv            []  2016-03-05      waamv           1          District
#
#           first_event_code  first_event_id      ...      state_prov  \
# key                                             ...
# 2016waahs            WAAHS    17473.000000      ...              WA
# 2016waamv            WAAMV    17463.000000      ...              WA
#
#                       timezone                                      webcasts  \
# key
# 2016waahs  America/Los_Angeles  [{'channel': '17281416', 'type': 'ustream'}]
# 2016waamv  America/Los_Angeles  [{'channel': '17281416', 'type': 'ustream'}]
#
#                            website     week  year district_abbreviation  \
# key
# 2016waahs   http://www.firstwa.org 5.000000  2016                   pnw
# 2016waamv  http://www.firstwa.org/ 1.000000  2016                   pnw
#
#            district_display_name district_key district_year
# key
# 2016waahs      Pacific Northwest      2016pnw   2016.000000
# 2016waamv      Pacific Northwest      2016pnw   2016.000000
#
# [2 rows x 32 columns]

# %%
events.shape
# Out:
# (203, 32)

# %%
events = api.get_events(sn, year=2016, response="simple")

# %%
events.tail()
# Out:
#                  city country    end_date event_code  event_type  \
# key
# 2016week0   Merrimack     USA  2016-02-20      week0         100
# 2016wimi    Milwaukee     USA  2016-03-26       wimi           0
# 2016wiwi      Wolcott     USA  2016-06-11       wiwi          99
# 2016wmri      Zeeland     USA  2016-10-29       wmri          99
# 2016wvrox  Morgantown     USA  2016-08-06      wvrox          99
#
#                                           name  start_date state_prov  year  \
# key
# 2016week0                               Week 0  2016-02-20         NH  2016
# 2016wimi                    Wisconsin Regional  2016-03-23         WI  2016
# 2016wiwi         Where is Wolcott Invitational  2016-06-11         CT  2016
# 2016wmri   West Michigan Robotics Invitational  2016-10-29         MI  2016
# 2016wvrox       West Virginia RObotics eXtreme  2016-08-05         WV  2016
#
#           district_abbreviation district_display_name district_key  \
# key
# 2016week0                  None                  None         None
# 2016wimi                   None                  None         None
# 2016wiwi                   None                  None         None
# 2016wmri                   None                  None         None
# 2016wvrox                  None                  None         None
#
#            district_year
# key
# 2016week0            nan
# 2016wimi             nan
# 2016wiwi             nan
# 2016wmri             nan
# 2016wvrox            nan

# %%
events.shape
# Out:
# (203, 13)

# %%
events = api.get_events(sn, year=2016, response="keys")

# %%
events.head()
# Out:
#         key
# 0  2016abca
# 1  2016alhu
# 2   2016arc
# 3  2016arlr
# 4  2016aroz

# %%
events.shape
# Out:
# (203, 1)

# %%
events = api.get_events(sn, district="2017pnw")

# %%
events.tail()
# Out:
#                                                    address          city  \
# key
# 2017waamv        28900 124th Ave SE, Auburn, WA 98092, USA        Auburn
# 2017waell  400 E University Way, Ellensburg, WA 98926, USA    Ellensburg
# 2017wamou           314 N 9th St, Mt Vernon, WA 98273, USA  Mount Vernon
# 2017wasno       7401 144th Pl SE, Snohomish, WA 98296, USA     Snohomish
# 2017waspo       8301 E Buckeye Ave, Spokane, WA 99212, USA       Spokane
#
#           country district.abbreviation district.display_name district.key  \
# key
# 2017waamv     USA                   pnw     Pacific Northwest      2017pnw
# 2017waell     USA                   pnw     Pacific Northwest      2017pnw
# 2017wamou     USA                   pnw     Pacific Northwest      2017pnw
# 2017wasno     USA                   pnw     Pacific Northwest      2017pnw
# 2017waspo     USA                   pnw     Pacific Northwest      2017pnw
#
#            district.year division_keys    end_date event_code  ...   \
# key                                                            ...
# 2017waamv           2017            []  2017-03-05      waamv  ...
# 2017waell           2017            []  2017-03-18      waell  ...
# 2017wamou           2017            []  2017-03-19      wamou  ...
# 2017wasno           2017            []  2017-03-26      wasno  ...
# 2017waspo           2017            []  2017-03-04      waspo  ...
#
#            playoff_type_string postal_code                     short_name  \
# key
# 2017waamv                 None       98092            Auburn Mountainview
# 2017waell                 None       98926  Central Washington University
# 2017wamou                 None       98273                   Mount Vernon
# 2017wasno                 None       98296                   Glacier Peak
# 2017waspo                 None       99212                    West Valley
#
#            start_date state_prov             timezone  \
# key
# 2017waamv  2017-03-03         WA  America/Los_Angeles
# 2017waell  2017-03-16         WA  America/Los_Angeles
# 2017wamou  2017-03-17         WA  America/Los_Angeles
# 2017wasno  2017-03-24         WA  America/Los_Angeles
# 2017waspo  2017-03-02         WA  America/Los_Angeles
#
#                                                     webcasts  \
# key
# 2017waamv  [{'channel': '17281416', 'type': 'ustream'}, {...
# 2017waell     [{'channel': 'firstwa_red', 'type': 'twitch'}]
# 2017wamou    [{'channel': 'firstwa_blue', 'type': 'twitch'}]
# 2017wasno    [{'channel': 'firstwa_blue', 'type': 'twitch'}]
# 2017waspo     [{'channel': 'firstwa_red', 'type': 'twitch'}]
#
#                            website week  year
# key
# 2017waamv  http://www.firstwa.org/    0  2017
# 2017waell   http://www.firstwa.org    2  2017
# 2017wamou  http://www.firstwa.org/    2  2017
# 2017wasno  http://www.firstwa.org/    3  2017
# 2017waspo   http://www.firstwa.org    0  2017
#
# [5 rows x 32 columns]

# %%
events.shape
# Out:
# (10, 32)

# %%
events = api.get_events(sn, district="2017pnw", response="simple")

# %%
events.head()
# Out:
#                   city country district.abbreviation district.display_name  \
# key
# 2017orlak  Lake Oswego     USA                   pnw     Pacific Northwest
# 2017orore    Clackamas     USA                   pnw     Pacific Northwest
# 2017orwil  Wilsonville     USA                   pnw     Pacific Northwest
# 2017pncmp       Cheney     USA                   pnw     Pacific Northwest
# 2017waahs       Auburn     USA                   pnw     Pacific Northwest
#
#           district.key  district.year    end_date event_code  event_type  \
# key
# 2017orlak      2017pnw           2017  2017-04-01      orlak           1
# 2017orore      2017pnw           2017  2017-03-25      orore           1
# 2017orwil      2017pnw           2017  2017-03-11      orwil           1
# 2017pncmp      2017pnw           2017  2017-04-08      pncmp           2
# 2017waahs      2017pnw           2017  2017-04-02      waahs           1
#
#                                                         name  start_date  \
# key
# 2017orlak                   PNW District - Lake Oswego Event  2017-03-30
# 2017orore  PNW District - Clackamas Academy of Industrial...  2017-03-23
# 2017orwil                   PNW District - Wilsonville Event  2017-03-09
# 2017pncmp            Pacific Northwest District Championship  2017-04-05
# 2017waahs                        PNW District - Auburn Event  2017-03-31
#
#           state_prov  year
# key
# 2017orlak         OR  2017
# 2017orore         OR  2017
# 2017orwil         OR  2017
# 2017pncmp         WA  2017
# 2017waahs         WA  2017

# %%
events.shape
# Out:
# (10, 13)

# %%
events = api.get_events(sn, district="2017pnw", response="keys")

# %%
events.head()
# Out:
#          key
# 0  2017orlak
# 1  2017orore
# 2  2017orwil
# 3  2017pncmp
# 4  2017waahs

# %%
events = api.get_events(sn, team="frc1318", year=2017)

# %%
events.head()
# Out:
#                                                      address     city country  \
# key
# 2017cmptx  1001 Avenida De Las Americas, Houston, TX 7701...  Houston     USA
# 2017pncmp                  526 5th St, Cheney, WA 99004, USA   Cheney     USA
# 2017tur    1001 Avenida De Las Americas, Houston, TX 7701...  Houston     USA
# 2017waahs               711 E Main St, Auburn, WA 98002, USA   Auburn     USA
# 2017waamv          28900 124th Ave SE, Auburn, WA 98092, USA   Auburn     USA
#
#                                                division_keys    end_date  \
# key
# 2017cmptx  [2017carv, 2017gal, 2017hop, 2017new, 2017roe,...  2017-04-22
# 2017pncmp                                                 []  2017-04-08
# 2017tur                                                   []  2017-04-22
# 2017waahs                                                 []  2017-04-02
# 2017waamv                                                 []  2017-03-05
#
#           event_code  event_type      event_type_string first_event_code  \
# key
# 2017cmptx      cmptx           4    Championship Finals            CMPTX
# 2017pncmp      pncmp           2  District Championship            PNCMP
# 2017tur          tur           3  Championship Division              TUR
# 2017waahs      waahs           1               District            WAAHS
# 2017waamv      waamv           1               District            WAAMV
#
#            first_event_id      ...       state_prov             timezone  \
# key                            ...
# 2017cmptx             nan      ...               TX      America/Chicago
# 2017pncmp    22651.000000      ...               WA  America/Los_Angeles
# 2017tur               nan      ...               TX      America/Chicago
# 2017waahs    22639.000000      ...               WA  America/Los_Angeles
# 2017waamv    22629.000000      ...               WA  America/Los_Angeles
#
#                                                     webcasts  \
# key
# 2017cmptx   [{'channel': 'firstinspires', 'type': 'twitch'}]
# 2017pncmp  [{'channel': 'firstwa_red', 'type': 'twitch'},...
# 2017tur    [{'channel': 'FIRSTInspires_Turing', 'type': '...
# 2017waahs    [{'channel': 'firstwa_blue', 'type': 'twitch'}]
# 2017waamv  [{'channel': '17281416', 'type': 'ustream'}, {...
#
#                            website     week  year district_abbreviation  \
# key
# 2017cmptx              http://None      nan  2017                  None
# 2017pncmp   http://www.firstwa.org 5.000000  2017                   pnw
# 2017tur                       None      nan  2017                  None
# 2017waahs   http://www.firstwa.org 4.000000  2017                   pnw
# 2017waamv  http://www.firstwa.org/ 0.000000  2017                   pnw
#
#            district_display_name district_key  district_year
# key
# 2017cmptx                   None         None            nan
# 2017pncmp      Pacific Northwest      2017pnw    2017.000000
# 2017tur                     None         None            nan
# 2017waahs      Pacific Northwest      2017pnw    2017.000000
# 2017waamv      Pacific Northwest      2017pnw    2017.000000
#
# [5 rows x 32 columns]

# %%
events.shape
# Out:
# (8, 32)

# %%
events = api.get_events(sn, team="frc1318", year=2016, response="simple")

# %%
events.head()
# Out:
#                  city country    end_date event_code  event_type  \
# key
# 2016arc     St. Louis     USA  2016-04-30        arc           3
# 2016orphi   Philomath     USA  2016-03-26      orphi           1
# 2016pncmp    Portland     USA  2016-04-09      pncmp           2
# 2016waamv      Auburn     USA  2016-03-05      waamv           1
# 2016waell  Ellensburg     USA  2016-03-19      waell           1
#
#                                                         name  start_date  \
# key
# 2016arc                                  Archimedes Division  2016-04-27
# 2016orphi                     PNW District - Philomath Event  2016-03-24
# 2016pncmp  Pacific Northwest District Championship sponso...  2016-04-06
# 2016waamv           PNW District - Auburn Mountainview Event  2016-03-03
# 2016waell  PNW District - Central Washington University E...  2016-03-17
#
#           state_prov  year district_abbreviation district_display_name  \
# key
# 2016arc           MO  2016                  None                  None
# 2016orphi         OR  2016                   pnw     Pacific Northwest
# 2016pncmp         OR  2016                   pnw     Pacific Northwest
# 2016waamv         WA  2016                   pnw     Pacific Northwest
# 2016waell         WA  2016                   pnw     Pacific Northwest
#
#           district_key  district_year
# key
# 2016arc           None            nan
# 2016orphi      2016pnw    2016.000000
# 2016pncmp      2016pnw    2016.000000
# 2016waamv      2016pnw    2016.000000
# 2016waell      2016pnw    2016.000000

# %%
events = api.get_events(sn, team="frc1318", year=2016, response="keys")

# %%
events.head()
# Out:
#          key
# 0    2016arc
# 1  2016orphi
# 2  2016pncmp
# 3  2016waamv
# 4  2016waell

# %%
event = api.get_events(sn, event="2017tur")

# %%
event
# Out:
#                                                    address     city country  \
# key
# 2017tur  1001 Avenida De Las Americas, Houston, TX 7701...  Houston     USA
#
#          district division_keys    end_date event_code  event_type  \
# key
# 2017tur       nan            []  2017-04-22        tur           3
#
#              event_type_string first_event_code  ...   \
# key                                              ...
# 2017tur  Championship Division              TUR  ...
#
#                        playoff_type_string postal_code short_name  start_date  \
# key
# 2017tur  Elimination Bracket (8 Alliances)       77010     Turing  2017-04-19
#
#          state_prov         timezone  \
# key
# 2017tur          TX  America/Chicago
#
#                                                   webcasts website  week  year
# key
# 2017tur  [{'channel': 'FIRSTInspires_Turing', 'type': '...     nan   nan  2017
#
# [1 rows x 29 columns]

# %%
event.shape
# Out:
# (1, 29)

# %%
event = api.get_events(sn, event="2017tur", response="simple")

# %%
event
# Out:
#             city country  district    end_date event_code  event_type  \
# key
# 2017tur  Houston     USA       nan  2017-04-22        tur           3
#
#                     name  start_date state_prov  year
# key
# 2017tur  Turing Division  2017-04-19         TX  2017

# %%
event.shape
# Out:
# (1, 10)

# %% [markdown]
# ### get_rankings()

# %%
rankings = api.get_rankings(sn, "2017pnw")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f3ec25444252> in <module>()
# ----> 1 rankings = api.get_rankings(sn, "2017pnw")
#
# AttributeError: module 'tbap.api' has no attribute 'get_rankings'

# %%
rankings.query("team_key == 'frc1318'")
