# %% [markdown]
# # Imports

# %%
import json
import re
import datetime
from collections import OrderedDict

import pandas as pd
import pandas.io.json as pj
from IPython.core.debugger import set_trace

import tbap.api as api
import tbap.server as server

# %% [markdown]
# ### Create Session

# %%
key = "6Sx6a2gOyNWwNNTAd9UYBOpWp7MxaNrZgO4CqConwJwwDooKQV3DbZXvnk8TBL7A"
sn = api.Session(key)
snj = api.Session(key, data_format="json")

# Display floating point numbers in fixed format within dataframes.
pd.options.display.float_format = '{:f}'.format

# %% [markdown]
# # Examples

# %% [markdown]
# ## get_teams()

# %%
result = api.get_teams(sn, 1)

# %%
result.head()
# Out:
#   address              city country gmaps_place_id gmaps_url  \
# 0    None        New London     USA           None      None
# 1    None        Manchester     USA           None      None
# 2    None  Rockville Centre     USA           None      None
# 3    None              Novi     USA           None      None
# 4    None     Little Silver     USA           None      None
#
#   home_championship.2017 home_championship.2018     key   lat   lng  \
# 0              St. Louis                Detroit  frc500  None  None
# 1              St. Louis                Detroit  frc501  None  None
# 2              St. Louis                Detroit  frc502  None  None
# 3              St. Louis                Detroit  frc503  None  None
# 4              St. Louis                Detroit  frc504  None  None
#
#   location_name                                           motto  \
# 0          None                                            None
# 1          None  Meeting the challenge, exceeding the standard.
# 2          None                                            None
# 3          None                                    A Leap Ahead
# 4          None                                            None
#
#                                                 name           nickname  \
# 0  U.S. Coast Guard Academy, USCG Foundation, USC...  Team 500/Team USA
# 1  BURNDY / Dyn / UL / 4-H & Manchester West High...   The PowerKnights
# 2
# 3  Magna Seating Systems (Primary Sponsor)/Denso/...         Frog Force
# 4
#
#   postal_code  rookie_year     state_prov  team_number  \
# 0        None       2001.0             CT          500
# 1       03102       2001.0  New Hampshire          501
# 2        None          NaN             NY          502
# 3       48375       2001.0       Michigan          503
# 4        None          NaN             NJ          504
#
#                        website
# 0    http://www.cgateam500.org
# 1  http://www.powerknights.com
# 2                         None
# 3  http://www.frogforce503.org
# 4                         None

# %%
result = api.get_teams(sn, 1, response="simple")

# %%
result.head()
# Out:
#                city country     key  \
# 0        New London     USA  frc500
# 1        Manchester     USA  frc501
# 2  Rockville Centre     USA  frc502
# 3              Novi     USA  frc503
# 4     Little Silver     USA  frc504
#
#                                                 name           nickname  \
# 0  U.S. Coast Guard Academy, USCG Foundation, USC...  Team 500/Team USA
# 1  BURNDY / Dyn / UL / 4-H & Manchester West High...   The PowerKnights
# 2
# 3  Magna Seating Systems (Primary Sponsor)/Denso/...         Frog Force
# 4
#
#       state_prov  team_number
# 0             CT          500
# 1  New Hampshire          501
# 2             NY          502
# 3       Michigan          503
# 4             NJ          504

# %%
result = api.get_teams(sn, 1, response="keys")

# %%
result.head()
# Out:
#         0
# 0  frc500
# 1  frc501
# 2  frc502
# 3  frc503
# 4  frc504

# %%
result = api.get_teams(sn, 1, year=2016)

# %%
result.head()
# Out:
#   address          city country gmaps_place_id gmaps_url  \
# 0    None    Manchester     USA           None      None
# 1    None          Novi     USA           None      None
# 2    None       Bedford     USA           None      None
# 3    None  Miller Place     USA           None      None
# 4    None   Cedar Falls     USA           None      None
#
#   home_championship.2017 home_championship.2018     key   lat   lng  \
# 0              St. Louis                Detroit  frc501  None  None
# 1              St. Louis                Detroit  frc503  None  None
# 2              St. Louis                Detroit  frc509  None  None
# 3              St. Louis                Detroit  frc514  None  None
# 4              St. Louis                Detroit  frc525  None  None
#
#   location_name                                           motto  \
# 0          None  Meeting the challenge, exceeding the standard.
# 1          None                                    A Leap Ahead
# 2          None                       Taking the World by STORM
# 3          None                                    Done is good
# 4          None      Students Working Around Robotic Technology
#
#                                                 name               nickname  \
# 0  BURNDY / Dyn / UL / 4-H & Manchester West High...       The PowerKnights
# 1  Magna Seating Systems (Primary Sponsor)/Denso/...             Frog Force
# 2      Bedford School District & Bedford High School              Red Storm
# 3  Switches and Sensors Inc/Alternative Parts Inc...  Miller Place Robotics
# 4  Cedar Falls Community Schools/John Deere/PTC/R...              Swartdogs
#
#   postal_code  rookie_year     state_prov  team_number  \
# 0       03102         2001  New Hampshire          501
# 1       48375         2001       Michigan          503
# 2       03110         2001  New Hampshire          509
# 3       11764         2001       New York          514
# 4       50613         2001           Iowa          525
#
#                                website
# 0          http://www.powerknights.com
# 1          http://www.frogforce503.org
# 2  http://www.redstorm509.appspot.com/
# 3                 https://team514.com/
# 4          http://www.525swartdogs.org

# %%
result = api.get_teams(sn, 1, year=2016, response="simple")

# %%
result.head()
# Out:
#            city country     key  \
# 0    Manchester     USA  frc501
# 1          Novi     USA  frc503
# 2       Bedford     USA  frc509
# 3  Miller Place     USA  frc514
# 4   Cedar Falls     USA  frc525
#
#                                                 name               nickname  \
# 0  BURNDY / Dyn / UL / 4-H & Manchester West High...       The PowerKnights
# 1  Magna Seating Systems (Primary Sponsor)/Denso/...             Frog Force
# 2      Bedford School District & Bedford High School              Red Storm
# 3  Switches and Sensors Inc/Alternative Parts Inc...  Miller Place Robotics
# 4  Cedar Falls Community Schools/John Deere/PTC/R...              Swartdogs
#
#       state_prov  team_number
# 0  New Hampshire          501
# 1       Michigan          503
# 2  New Hampshire          509
# 3       New York          514
# 4           Iowa          525

# %%
result = api.get_teams(sn, 1, year=2016, response="keys")

# %%
result.head()
# Out:
#         0
# 0  frc501
# 1  frc503
# 2  frc509
# 3  frc514
# 4  frc525

# %%
result = api.get_teams(sn, 1, response="keys")

# %%
api.send_request(sn, ["districts", 2017])
# Out:
#   abbreviation       display_name      key  year
# 0          chs         Chesapeake  2017chs  2017
# 1          fim           Michigan  2017fim  2017
# 2           in            Indiana   2017in  2017
# 3          isr             Israel  2017isr  2017
# 4          mar       Mid-Atlantic  2017mar  2017
# 5           nc     North Carolina   2017nc  2017
# 6           ne        New England   2017ne  2017
# 7          ont            Ontario  2017ont  2017
# 8          pch          Peachtree  2017pch  2017
# 9          pnw  Pacific Northwest  2017pnw  2017

# %%
teams = api.get_teams(sn, district="2017pnw")

# %%
teams.head()
# Out:
#   address         city country gmaps_place_id gmaps_url  \
# 0    None      Seattle     USA           None      None
# 1    None    Sammamish     USA           None      None
# 2    None     Issaquah     USA           None      None
# 3    None      Lebanon     USA           None      None
# 4    None  Wilsonville     USA           None      None
#
#   home_championship.2017 home_championship.2018      key   lat   lng  \
# 0                Houston                Houston  frc1258  None  None
# 1                Houston                Houston  frc1294  None  None
# 2                Houston                Houston  frc1318  None  None
# 3                Houston                Houston  frc1359  None  None
# 4                Houston                Houston  frc1425  None  None
#
#   location_name                                              motto  \
# 0          None                                               None
# 1          None  You get out of it, what you put into it. Stop ...
# 2          None                                 Robots Don't Quit!
# 3          None                              Prepare to be boarded
# 4          None                  Building Robots...Building People
#
#                                                 name  \
# 0  The Boeing Company & Seattle Lutheran High School
# 1  Lake Washington Schools Foundation/Microsoft/d...
# 2  The Boeing Company/State of Washington OSPI/Tr...
# 3  Linn Benton Community College/Oregon Dept of E...
# 4  Xerox/Lam Research/City Of Wilsonville/Maxim I...
#
#                     nickname postal_code  rookie_year  state_prov  \
# 0                     SeaBot       98116         2004  Washington
# 1                    Top Gun       98074         2004  Washington
# 2  Issaquah Robotics Society       98027         2004  Washington
# 3                  Scalawags       97355         2004      Oregon
# 4            Error Code Xero       97070         2004      Oregon
#
#    team_number                                            website
# 0         1258  http://www.seattlelutheran.org/events/robotics...
# 1         1294                            http://www.team1294.org
# 2         1318                            http://www.team1318.org
# 3         1359                           http://www.scalawags.org
# 4         1425                 http://www.wilsonvillerobotics.com

# %%
teams = api.get_teams(sn, district="2017pnw", response="simple")

# %%
teams.head()
# Out:
#           city country      key  \
# 0      Seattle     USA  frc1258
# 1    Sammamish     USA  frc1294
# 2     Issaquah     USA  frc1318
# 3      Lebanon     USA  frc1359
# 4  Wilsonville     USA  frc1425
#
#                                                 name  \
# 0  The Boeing Company & Seattle Lutheran High School
# 1  Lake Washington Schools Foundation/Microsoft/d...
# 2  The Boeing Company/State of Washington OSPI/Tr...
# 3  Linn Benton Community College/Oregon Dept of E...
# 4  Xerox/Lam Research/City Of Wilsonville/Maxim I...
#
#                     nickname  state_prov  team_number
# 0                     SeaBot  Washington         1258
# 1                    Top Gun  Washington         1294
# 2  Issaquah Robotics Society  Washington         1318
# 3                  Scalawags      Oregon         1359
# 4            Error Code Xero      Oregon         1425

# %%
teams = api.get_teams(sn, district="2017pnw", response="keys")

# %%
teams.head()
# Out:
#          0
# 0  frc1258
# 1  frc1294
# 2  frc1318
# 3  frc1359
# 4  frc1425

# %%
api.send_request(sn, ["team", "frc1318", "events", "simple"]).head()
# Out:
#        city country district    end_date event_code  event_type      key  \
# 0  Portland     USA     None  2004-03-06         or           0   2004or
# 1  Portland     USA     None  2005-03-12         or           0   2005or
# 2     Davis     USA     None  2006-03-25        sac           0  2006sac
# 3  Portland     USA     None  2006-03-04         wa           0   2006wa
# 4  Portland     USA     None  2007-03-03         or           0   2007or
#
#                          name  start_date state_prov  year
# 0  Pacific Northwest Regional  2004-03-04         OR  2004
# 1  Pacific Northwest Regional  2005-03-10         OR  2005
# 2   Davis Sacramento Regional  2006-03-23         CA  2006
# 3  Pacific Northwest Regional  2006-03-02         OR  2006
# 4  Pacific Northwest Regional  2007-03-01         OR  2007

# %%
teams = api.get_teams(sn, event="2017tur")

# %%
teams.head()
# Out:
#   address             city country gmaps_place_id gmaps_url  \
# 0    None  Fort Lauderdale     USA           None      None
# 1    None          Phoenix     USA           None      None
# 2    None     Myrtle Beach     USA           None      None
# 3    None         Rockwall     USA           None      None
# 4    None         Issaquah     USA           None      None
#
#   home_championship.2017 home_championship.2018      key   lat   lng  \
# 0                Houston                Houston   frc108  None  None
# 1                Houston                Houston  frc1165  None  None
# 2                Houston                Houston  frc1287  None  None
# 3                Houston                Houston  frc1296  None  None
# 4                Houston                Houston  frc1318  None  None
#
#   location_name                                    motto  \
# 0          None            "Teamwork through Technology"
# 1          None  If it was easy, you didn't do it right.
# 2          None           Best work, First time, On time
# 3          None                       It's a cat(apult).
# 4          None                       Robots Don't Quit!
#
#                                                 name  \
# 0  Motorola Solutions Foundation/Florida Power & ...
# 1              Bechtel & Paradise Valley High School
# 2  Horry County Schools/Grand Strand Technology C...
# 3  Rockwall Makerspace/Innovation First Internati...
# 4  The Boeing Company/State of Washington OSPI/Tr...
#
#                     nickname postal_code  rookie_year      state_prov  \
# 0      SigmaC@T Robotic Team       33311         1995         Florida
# 1              Team Paradise       85032         2003         Arizona
# 2           Aluminum Assault       29579         2004  South Carolina
# 3         Full Metal Jackets       75087         2004           Texas
# 4  Issaquah Robotics Society       98027         2004      Washington
#
#    team_number                          website
# 0          108         http://www.sigmacats.org
# 1         1165      http://teamparadise1165.com
# 2         1287       http://www.FRCTeam1287.com
# 3         1296  http://www.rockwallrobotics.com
# 4         1318          http://www.team1318.org

# %%
teams = api.get_teams(sn, event="2017tur", response="simple")

# %%
teams.head()
# Out:
#               city country      key  \
# 0  Fort Lauderdale     USA   frc108
# 1          Phoenix     USA  frc1165
# 2     Myrtle Beach     USA  frc1287
# 3         Rockwall     USA  frc1296
# 4         Issaquah     USA  frc1318
#
#                                                 name  \
# 0  Motorola Solutions Foundation/Florida Power & ...
# 1              Bechtel & Paradise Valley High School
# 2  Horry County Schools/Grand Strand Technology C...
# 3  Rockwall Makerspace/Innovation First Internati...
# 4  The Boeing Company/State of Washington OSPI/Tr...
#
#                     nickname      state_prov  team_number
# 0      SigmaC@T Robotic Team         Florida          108
# 1              Team Paradise         Arizona         1165
# 2           Aluminum Assault  South Carolina         1287
# 3         Full Metal Jackets           Texas         1296
# 4  Issaquah Robotics Society      Washington         1318

# %%
teams = api.get_teams(sn, event="2017tur", response="keys")

# %%
teams.head()
# Out:
#          0
# 0   frc108
# 1  frc1165
# 2  frc1287
# 3  frc1296
# 4  frc1318

# %% [markdown]
# ### get_team()

# %%
team = api.get_team(sn, "frc1318")

# %%
team
# Out:
#   address      city country gmaps_place_id gmaps_url home_championship.2017  \
# 0    None  Issaquah     USA           None      None                Houston
#
#   home_championship.2018      key   lat   lng location_name  \
# 0                Houston  frc1318  None  None          None
#
#                 motto                                               name  \
# 0  Robots Don't Quit!  The Boeing Company/State of Washington OSPI/Tr...
#
#                     nickname postal_code  rookie_year  state_prov  \
# 0  Issaquah Robotics Society       98027         2004  Washington
#
#    team_number                  website
# 0         1318  http://www.team1318.org

# %%
team = api.get_team(sn, "frc1318", response="simple")

# %%
team
# Out:
#        city country      key  \
# 0  Issaquah     USA  frc1318
#
#                                                 name  \
# 0  The Boeing Company/State of Washington OSPI/Tr...
#
#                     nickname  state_prov  team_number
# 0  Issaquah Robotics Society  Washington         1318

# %%
team = api.get_team(sn, "frc1318", response="years_participated")

# %%
team.head()
# Out:
#       0
# 0  2004
# 1  2005
# 2  2006
# 3  2007
# 4  2008

# %%
team = api.get_team(sn, "frc1318", response="robots")

# %%
team
# Out:
#             key robot_name team_key  year
# 0  frc1318_2015  Toothless  frc1318  2015
# 1  frc1318_2016      Gimli  frc1318  2016
# 2  frc1318_2017   Cerberus  frc1318  2017
# 3  frc1318_2018   Cerberus  frc1318  2018

# %% [markdown]
# ### get_event_team_status()

# %%
team = api.get_event_team_status(sn, "2017tur", "frc1318")

# %%
team.head()
# Out:
# alliance_backup                                       None
# alliance_name                                   Alliance 3
# alliance_number                                          3
# alliance_pick                                            0
# alliance_status_str    <b>Captain</b> of <b>Alliance 3</b>
# dtype: object

# %% [markdown]
# ### get_media()

# %%
media = api.get_media(sn, "frc1318", "2017")

# %%
media
# Out:
#    details.author_id details.author_name  \
# 0                nan                 NaN
# 1  1116937831.000000    1stroboticsrocks
#
#                            details.author_url  details.height  \
# 0                                         NaN             nan
# 1  https://www.instagram.com/1stroboticsrocks             nan
#
#                                         details.html  \
# 0                                                NaN
# 1  <blockquote class="instagram-media" data-instg...
#
#                  details.media_id details.provider_name  \
# 0                             NaN                   NaN
# 1  1512600524829256257_1116937831             Instagram
#
#         details.provider_url  details.thumbnail_height  \
# 0                        NaN                       nan
# 1  https://www.instagram.com                640.000000
#
#                                details.thumbnail_url  details.thumbnail_width  \
# 0                                                NaN                      nan
# 1  https://scontent-ort2-1.cdninstagram.com/t51.2...               640.000000
#
#                                        details.title details.type  \
# 0                                                NaN          NaN
# 1  FRC 1318 @ 2017 FIRST Robotics World Champions...         rich
#
#   details.version  details.width  foreign_key  preferred             type
# 0             NaN            nan      3FRPrZ1       True            imgur
# 1             1.0     658.000000  BT91inJhGpB       True  instagram-image

# %% [markdown]
# ### get_social_media()

# %%
media2 = api.get_social_media(sn, "frc1318")

# %%
media2
# Out:
#   foreign_key  preferred              type
# 0     frc1318      False  facebook-profile
# 1     frc1318      False   twitter-profile
